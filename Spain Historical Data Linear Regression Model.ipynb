# %%
# !pip install scikit-learn
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline #this is used for visualizations

# %%
from sklearn.linear_model import LinearRegression

# %%
#to read in our data

data = pd.read_csv('spain_weather.csv')

# %%
data.info() 
#non-null is good because we have no NA values, yet for the last three columns we are missings 1300 entires, but those arent going to be used in this analysis anyways
#as of now, we are dealing with floats and objects, so if I want to use this dataset, I need to change the date to be a float or int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1745 entries, 0 to 1744
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1745 non-null   object
#  1   country    1745 non-null   object
#  2   city       1745 non-null   object
#  3   Latitude   1745 non-null   float64
#  4   Longitude  1745 non-null   float64
#  5   tavg       1739 non-null   float64
#  6   tmin       1744 non-null   float64
#  7   tmax       1743 non-null   float64
#  8   wdir       462 non-null    float64
#  9   wspd       462 non-null    float64
#  10  pres       462 non-null    float64
# dtypes: float64(8), object(3)
# memory usage: 150.1+ KB

# %%
#clean/parse data first
df = pd.DataFrame(data)
df.head(262)
#where tavg = NaN, delete OR figure out another way to work around it i guess
#something I noticed immediatly is that some dates are in day/mon/year format while others are using dashes instead of backslashes?
# Out:
#            date country    city   Latitude  Longitude  tavg  tmin  tmax  wdir  \
# 0      1/1/2018   Spain  Madrid  40.416775   -3.70379   4.8   1.5   9.9   NaN
# 1      2/1/2018   Spain  Madrid  40.416775   -3.70379   7.8   5.2  11.3   NaN
# 2      3/1/2018   Spain  Madrid  40.416775   -3.70379   8.9   5.8  14.8   NaN
# 3      4/1/2018   Spain  Madrid  40.416775   -3.70379   7.5   3.6  13.4   NaN
# 4      5/1/2018   Spain  Madrid  40.416775   -3.70379   4.8   2.6   6.3   NaN
# ..          ...     ...     ...        ...        ...   ...   ...   ...   ...
# 257  15-09-2018   Spain  Madrid  40.416775   -3.70379  22.0  17.2  27.1   NaN
# 258  16-09-2018   Spain  Madrid  40.416775   -3.70379  24.8  15.0  28.1   NaN
# 259  17-09-2018   Spain  Madrid  40.416775   -3.70379   NaN  15.7  27.3   NaN
# 260  18-09-2018   Spain  Madrid  40.416775   -3.70379  20.7  14.4  25.2   NaN
# 261  19-09-2018   Spain  Madrid  40.416775   -3.70379  20.7  15.7  26.9   NaN
#
#      wspd  pres
# ...

# %%
#to visualize beforehand
#once data is cleaned, make x date and y tavg
sns.regplot(x= 'tmin', y= 'tmax', data=data)
# Out:
# <AxesSubplot:xlabel='tmin', ylabel='tmax'>
